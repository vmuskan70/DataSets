# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.isnull().fillna("")
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9795   False     False       False      False      False        False
# 9796   False     False       False      False      False        False
# 9797   False     False       False      False      False        False
# 9798   False     False       False      False      False        False
# 9799   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  State  Postal Code  Region  \
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   str
#  3   Ship Date      9800 non-null   str
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), str(15)
# ...

# %%
df[["Order ID","Order Date","Category","Sales"]]
# Out:
#             Order ID  Order Date         Category     Sales
# 0     CA-2017-152156  08/11/2017        Furniture  261.9600
# 1     CA-2017-152156  08/11/2017        Furniture  731.9400
# 2     CA-2017-138688  12/06/2017  Office Supplies   14.6200
# 3     US-2016-108966  11/10/2016        Furniture  957.5775
# 4     US-2016-108966  11/10/2016  Office Supplies   22.3680
# ...              ...         ...              ...       ...
# 9795  CA-2017-125920  21/05/2017  Office Supplies    3.7980
# 9796  CA-2016-128608  12/01/2016  Office Supplies   10.3680
# 9797  CA-2016-128608  12/01/2016       Technology  235.1880
# 9798  CA-2016-128608  12/01/2016       Technology   26.3760
# 9799  CA-2016-128608  12/01/2016       Technology   10.3840
#
# [9800 rows x 4 columns]

# %%
df[df["Category"]=="Furniture"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9786    9787  US-2015-114377  05/11/2015  05/11/2015        Same Day
# 9787    9788  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9788    9789  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9790    9791  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9792    9793  CA-2015-127166  21/05/2015  23/05/2015    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %%
df[(df["Region"]=="West")&(df["Category"]=="Technology")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 19        20  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 26        27  CA-2017-121755  16/01/2017  20/01/2017    Second Class
# 62        63  CA-2016-135545  24/11/2016  30/11/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9685    9686  CA-2018-118668  02/01/2018  04/01/2018    Second Class
# 9700    9701  CA-2018-154116  15/12/2018  19/12/2018  Standard Class
# 9725    9726  CA-2018-142293  17/09/2018  20/09/2018     First Class
# 9761    9762  CA-2015-121762  14/02/2015  18/02/2015  Standard Class
# 9764    9765  CA-2015-123855  18/06/2015  23/06/2015  Standard Class
#
#      Customer ID        Customer Name    Segment        Country  \
# 7       BH-11710      Brosina Hoffman   Consumer  United States
# ...

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
df["Region"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         South
# 1         South
# 2          West
# 3         South
# 4         South
#          ...
# 9795    Central
# 9796       East
# 9797       East
# 9798       East
# 9799       East
# Name: Region, Length: 9800, dtype: str>

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %%
df.groupby(["Category","Region"])["Sales"].sum()
# Out:
# Category         Region
# Furniture        Central    160317.4622
#                  East       206461.3880
#                  South      116531.4800
#                  West       245348.2455
# Office Supplies  Central    163590.2430
#                  East       199940.8110
#                  South      124424.7710
#                  West       217466.5090
# Technology       Central    168739.2080
#                  East       263116.5270
#                  South      148195.2080
#                  West       247404.9300
# Name: Sales, dtype: float64

# %%
df["Order ID"].nunique()
# Out:
# 4922

# %%
total_sales=df["Sales"].sum()
total_orders=df["Order ID"].nunique()
total_customers=df["Customer ID"].nunique()
average_order_value=total_sales/total_orders
average_customer_spending=total_sales/total_customers

print(f"Total Sales: ${total_sales:,}")
print(f"Total_Orders: {total_orders:,}")
print(f"Average Order Value: ${average_order_value:,.2f}")
print(f"Total Customers:{total_customers:,}")
print(f"Average Customer Spending: ${average_customer_spending:,}")
# Out:
# Total Sales: $2,261,536.7827
# Total_Orders: 4,922
# Average Order Value: $459.48
# Total Customers:793
# Average Customer Spending: $2,851.8748836065574

# %%
print("Total Rows/items:",len(df))
# Out:
# Total Rows/items: 9800

# %%
print("Unique Order Id: ",df["Order ID"].nunique())
print("Unique Customer ID : ",df["Customer ID"].nunique())
# Out:
# Unique Order Id:  4922
# Unique Customer ID :  793

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
("Missing Order IDs :", df["Order ID"].isnull().sum())
("Missing Customer IDs :", df["Customer ID"].isnull().sum())
# Out:
# ('Missing Customer IDs :', np.int64(0))

# %%
df["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9795      3.7980
# 9796     10.3680
# 9797    235.1880
# 9798     26.3760
# 9799     10.3840
# Name: Sales, Length: 9800, dtype: float64

# %%
df["Sales"].dtype
# Out:
# dtype('float64')

# %%
df["Sales"].sum()
# Out:
# np.float64(2261536.7827)

# %%
sales_per_order=df.groupby("Order ID")["Sales"].sum()
print(len(sales_per_order))
# Out:
# 4922

# %%
print(sales_per_order.sum())
# Out:
# 2261536.7827000003

# %%
df["Category"]
# Out:
# 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9795    Office Supplies
# 9796    Office Supplies
# 9797         Technology
# 9798         Technology
# 9799         Technology
# Name: Category, Length: 9800, dtype: str

# %%
df["Sub-Category"]
# Out:
# 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
#            ...
# 9795        Binders
# 9796            Art
# 9797         Phones
# 9798         Phones
# 9799    Accessories
# Name: Sub-Category, Length: 9800, dtype: str

# %%
category_sales=df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
subcategory_sales=df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False)
print(subcategory_sales)
# Out:
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Furnishings     89212.0180
# Paper           76828.3040
# Supplies        46420.3080
# Art             26705.4100
# Envelopes       16128.0460
# Labels          12347.7260
# Fasteners        3001.9600
# Name: Sales, dtype: float64

# %%
region_sales=df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
print(region_sales)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
state_sales=df.groupby("State")["Sales"].sum().sort_values(ascending=False)
print(state_sales)
# Out:
# State
# California              446306.4635
# New York                306361.1470
# Texas                   168572.5322
# Washington              135206.8500
# Pennsylvania            116276.6500
# Florida                  88436.5320
# Illinois                 79236.5170
# Michigan                 76136.0740
# Ohio                     75130.3500
# Virginia                 70636.7200
# North Carolina           55165.9640
# Indiana                  48718.4000
# Georgia                  48219.1100
# Kentucky                 36458.3900
# Arizona                  35272.6570
# New Jersey               34610.9720
# Colorado                 31841.5980
# Wisconsin                31173.4300
# Tennessee                30661.8730
# Minnesota                29863.1500
# Massachusetts            28634.4340
# Delaware                 27322.9990
# Maryland                 23705.5230
# Rhode Island             22525.0260
# Missouri                 22205.1500
# Oklahoma                 19683.3900
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
segment_sales=df.groupby("Segment")["Sales"].sum().sort_values(ascending=False)
print(segment_sales)
# Out:
# Segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: Sales, dtype: float64

# %%
customer_sales=df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False)
print(customer_sales)
# Out:
# Customer Name
# Sean Miller        25043.050
# Tamara Chand       19052.218
# Raymond Buch       15117.339
# Tom Ashbrook       14595.620
# Adrian Barton      14473.571
#                      ...
# Mitch Gastineau       16.739
# Carl Jackson          16.520
# Sung Chung            14.112
# Lela Donovan           5.304
# Thais Sissman          4.833
# Name: Sales, Length: 793, dtype: float64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   str
#  3   Ship Date      9800 non-null   str
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), str(15)
# ...

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"],format="mixed")

# %%
df['Month']=df["Order Date"].dt.month
df["Month Name"]=df["Order Date"].dt.month_name()
df["Year"]=df["Order Date"].dt.year

# %%
print(df["Month Name"])
# Out:
# 0         August
# 1         August
# 2       December
# 3       November
# 4       November
#           ...
# 9795         May
# 9796    December
# 9797    December
# 9798    December
# 9799    December
# Name: Month Name, Length: 9800, dtype: str

# %%
df["year-Month"]=df["Order Date"].dt.to_period("M")
